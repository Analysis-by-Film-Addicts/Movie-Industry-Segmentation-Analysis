# %%
# Dependencies
import pandas as pd
import pathlib
import numpy as np
import matplotlib.pyplot as plt
import re

# %% [markdown]
# # The below processes are to clean and merge movies & ratings raw data.

# %%
# Name the Movies CSV file
movies_file = pathlib.Path('Resources/IMDb_movies/IMDB movies.csv')

# Read and display the Movies CSV with Pandas
movies_df = pd.read_csv(movies_file)
movies_df.head()
# Out:
# C:\Users\grace\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  ...  \
# 0     None                      Alexander Black  ...
# 1     None                         Charles Tait  ...
# 2      NaN                            Urban Gad  ...
# 3  English                   Charles L. Gaskill  ...
# 4  Italian  Francesco Bertolini, Adolfo Padovan  ...
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
#
#                                          description avg_vote votes   budget  \
# 0  The adventures of a female reporter in the 1890s.      5.9   154      NaN
# 1  True story of notorious Australian outlaw Ned ...      6.1   589   $ 2250
# 2  Two men of high rank are both wooing the beaut...      5.8   188      NaN
# 3  The fabled queen of Egypt's affair with Roman ...      5.2   446  $ 45000
# 4  Loosely adapted from Dante's Divine Comedy and...      7.0  2237      NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                1.0
# 1               NaN                   NaN       NaN                7.0
# 2               NaN                   NaN       NaN                5.0
# 3               NaN                   NaN       NaN               25.0
# 4               NaN                   NaN       NaN               31.0
#
#    reviews_from_critics
# 0                   2.0
# 1                   7.0
# 2                   2.0
# 3                   3.0
# 4                  14.0
#
# [5 rows x 22 columns]

# %%
# movies_df.columns

# In the Movies data frame, most values are missing (blank), therefore column must be dropped in order not to loose any significant data 

movies_df['metascore'].isna().sum()
# Out:
# 72550

# %%
# Delete dropping columns that found to be irrelevant for analysis or have too many missing values. 

movies_df_removed = movies_df.drop(['description','metascore','writer','duration','production_company','budget','language'],axis=1)
 
movies_df_removed.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre           country  \
# 0  1894     1894-10-09                    Romance               USA
# 1  1906     1906-12-26    Biography, Crime, Drama         Australia
# 2  1911     1911-08-19                      Drama  Germany, Denmark
# 3  1912     1912-11-13             Drama, History               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy             Italy
#
#                               director  \
# 0                      Alexander Black
# 1                         Charles Tait
# 2                            Urban Gad
# 3                   Charles L. Gaskill
# 4  Francesco Bertolini, Adolfo Padovan
#
#                                               actors  avg_vote  votes  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...       5.9    154
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...       6.1    589
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...       5.8    188
# 3  Helen Gardner, Pearl Sindelar, Miss Fielding, ...       5.2    446
# 4  Salvatore Papa, Arturo Pirovano, Giuseppe de L...       7.0   2237
#
#   usa_gross_income worlwide_gross_income  reviews_from_users  \
# 0              NaN                   NaN                 1.0
# 1              NaN                   NaN                 7.0
# 2              NaN                   NaN                 5.0
# 3              NaN                   NaN                25.0
# 4              NaN                   NaN                31.0
#
#    reviews_from_critics
# 0                   2.0
# 1                   7.0
# 2                   2.0
# 3                   3.0
# 4                  14.0

# %%
# Set new index to 'imdb_title_id'

movies_df_removed_index = movies_df_removed.set_index("imdb_title_id")
movies_df_removed_index.head()
# Out:
#                                      title               original_title  year  \
# imdb_title_id
# tt0000009                       Miss Jerry                   Miss Jerry  1894
# tt0000574      The Story of the Kelly Gang  The Story of the Kelly Gang  1906
# tt0001892                   Den sorte drøm               Den sorte drøm  1911
# tt0002101                        Cleopatra                    Cleopatra  1912
# tt0002130                        L'Inferno                    L'Inferno  1911
#
#               date_published                      genre           country  \
# imdb_title_id
# tt0000009         1894-10-09                    Romance               USA
# tt0000574         1906-12-26    Biography, Crime, Drama         Australia
# tt0001892         1911-08-19                      Drama  Germany, Denmark
# tt0002101         1912-11-13             Drama, History               USA
# tt0002130         1911-03-06  Adventure, Drama, Fantasy             Italy
#
#                                           director  \
# imdb_title_id
# tt0000009                          Alexander Black
# tt0000574                             Charles Tait
# tt0001892                                Urban Gad
# tt0002101                       Charles L. Gaskill
# tt0002130      Francesco Bertolini, Adolfo Padovan
#
#                                                           actors  avg_vote  \
# imdb_title_id
# tt0000009      Blanche Bayliss, William Courtenay, Chauncey D...       5.9
# tt0000574      Elizabeth Tait, John Tait, Norman Campbell, Be...       6.1
# tt0001892      Asta Nielsen, Valdemar Psilander, Gunnar Helse...       5.8
# tt0002101      Helen Gardner, Pearl Sindelar, Miss Fielding, ...       5.2
# tt0002130      Salvatore Papa, Arturo Pirovano, Giuseppe de L...       7.0
#
#                votes usa_gross_income worlwide_gross_income  \
# imdb_title_id
# tt0000009        154              NaN                   NaN
# tt0000574        589              NaN                   NaN
# tt0001892        188              NaN                   NaN
# tt0002101        446              NaN                   NaN
# tt0002130       2237              NaN                   NaN
#
#                reviews_from_users  reviews_from_critics
# imdb_title_id
# tt0000009                     1.0                   2.0
# tt0000574                     7.0                   7.0
# tt0001892                     5.0                   2.0
# tt0002101                    25.0                   3.0
# tt0002130                    31.0                  14.0

# %%
movies_df_removed_index[['worlwide_gross_income','usa_gross_income']].isna().sum()
# Out:
# worlwide_gross_income    54839
# usa_gross_income         70529
# dtype: int64

# %%
# Replacing value in 'year' column and changing data type to integer
movies_df_removed_index['year'] = movies_df_removed_index['year'].replace(['TV Movie 2019'],'2019')
movies_df_removed_index['year'] = movies_df_removed_index['year'].astype('int64')

# Replacing value in 'date_published' column and changing data type to 'datetime'
movies_df_removed_index['date_published'] = movies_df_removed_index['date_published'].replace(['TV Movie 2019'],'2019')
movies_df_removed_index['date_published'] = movies_df_removed_index['date_published'].astype('datetime64[ns]')

# Filter based on years range from 1970 to 2020. 
movies_df_removed_index_1970 = movies_df_removed_index[(movies_df_removed_index['year']>=1970)]

movies_df_removed_index_1970
# Out:
#                                                           title  \
# imdb_title_id
# tt0017938                                La glace à trois faces
# tt0035423                                        Kate & Leopold
# tt0036606      Another time, another place - Una storia d'amore
# tt0039442                                         Habla, mudita
# tt0054724                                                Zombie
# ...                                                         ...
# tt9908390                                               Le lion
# tt9911196                        De Beentjes van Sint-Hildegard
# tt9911774                             Padmavyuhathile Abhimanyu
# tt9914286                                     Sokagin Çocuklari
# tt9914942                            La vida sense la Sara Amat
#
#                                original_title  year date_published  \
# imdb_title_id
# tt0017938              La glace à trois faces  1983     1983-03-13
# tt0035423                      Kate & Leopold  2001     2002-03-01
# tt0036606         Another Time, Another Place  1983     1983-07-15
# tt0039442                       Habla, mudita  1973     1973-06-01
# tt0054724                              Zombie  1971     1971-10-29
# ...                                       ...   ...            ...
# tt9908390                             Le lion  2020     2020-01-29
# tt9911196      De Beentjes van Sint-Hildegard  2020     2020-02-13
# tt9911774           Padmavyuhathile Abhimanyu  2019     2019-03-08
# tt9914286                   Sokagin Çocuklari  2019     2019-03-15
# tt9914942          La vida sense la Sara Amat  2019     2020-02-05
#
#                                   genre              country  \
# imdb_title_id
# tt0017938                Drama, Romance               France
# tt0035423      Comedy, Fantasy, Romance                  USA
# tt0036606                    Drama, War                   UK
# tt0039442                         Drama  Spain, West Germany
# tt0054724                        Horror                  USA
# ...                                 ...                  ...
# tt9908390                        Comedy      France, Belgium
# tt9911196                 Comedy, Drama          Netherlands
# tt9911774                         Drama                India
# tt9914286                 Drama, Family               Turkey
# tt9914942                         Drama                Spain
#
#                               director  \
# imdb_title_id
# tt0017938                 Jean Epstein
# tt0035423                James Mangold
# tt0036606              Michael Radford
# tt0039442      Manuel Gutiérrez Aragón
# tt0054724                   Del Tenney
# ...                                ...
# tt9908390       Ludovic Colbeau-Justin
# tt9911196              Johan Nijenhuis
# tt9911774              Vineesh Aaradya
# tt9914286            Ahmet Faik Akinci
# tt9914942                    Laura Jou
#
#                                                           actors  avg_vote  \
# imdb_title_id
# tt0017938      Jeanne Helbling, Suzy Pierson, Olga Day, Raymo...       7.0
# tt0035423      Meg Ryan, Hugh Jackman, Liev Schreiber, Brecki...       6.4
# tt0036606      Phyllis Logan, Giovanni Mauriello, Gianluca Fa...       6.5
# tt0039442      José Luis López Vázquez, Kiti Mánver, Francisc...       6.2
# tt0054724      William Joyce, Heather Hewitt, Walter Coy, Dan...       3.5
# ...                                                          ...       ...
# tt9908390      Dany Boon, Philippe Katerine, Anne Serra, Samu...       5.3
# tt9911196      Herman Finkers, Johanna ter Steege, Leonie ter...       7.7
# tt9911774      Anoop Chandran, Indrans, Sona Nair, Simon Brit...       7.9
# tt9914286      Ahmet Faik Akinci, Belma Mamati, Metin Keçeci,...       6.4
# tt9914942      Maria Morera Colomer, Biel Rossell Pelfort, Is...       6.7
#
#                votes usa_gross_income worlwide_gross_income  \
# imdb_title_id
# tt0017938        759              NaN                   NaN
# tt0035423      77852       $ 47121859            $ 76019048
# tt0036606        252              NaN                   NaN
# tt0039442        128              NaN                   NaN
# tt0054724       1214              NaN                   NaN
# ...              ...              ...                   ...
# tt9908390        398              NaN             $ 3507171
# tt9911196        724              NaN             $ 7299062
# tt9911774        265              NaN                   NaN
# tt9914286        194              NaN                $ 2833
# tt9914942        102              NaN               $ 59794
#
#                reviews_from_users  reviews_from_critics
# imdb_title_id
# tt0017938                     7.0                   4.0
# tt0035423                   341.0                 115.0
# tt0036606                     3.0                  10.0
# tt0039442                     2.0                   NaN
# tt0054724                    56.0                  40.0
# ...                           ...                   ...
# tt9908390                     NaN                   4.0
# tt9911196                     6.0                   4.0
# tt9911774                     NaN                   NaN
# tt9914286                     NaN                   NaN
# tt9914942                     NaN                   2.0
#
# [70264 rows x 14 columns]

# %%
movies_df_removed_index_1970[['worlwide_gross_income','usa_gross_income']].isna().sum()
# Out:
# worlwide_gross_income    39910
# usa_gross_income         55655
# dtype: int64

# %%
# split genre AND Country by comma delimiter and select first word
genre_split = movies_df_removed_index_1970["genre"].str.split(",", n=1, expand = True)
movies_df_removed_index_1970["genre_split"] = genre_split[0]
movies_df_removed_index_1970.columns

country_split = movies_df_removed_index_1970["country"].str.split(",", n=1, expand = True)
movies_df_removed_index_1970["country_split"] = country_split[0]
movies_df_removed_index_1970.head()
# Out:
# <ipython-input-9-195f3b4cdf27>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_df_removed_index_1970["genre_split"] = genre_split[0]
# <ipython-input-9-195f3b4cdf27>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_df_removed_index_1970["country_split"] = country_split[0]
#                                                           title  \
# imdb_title_id
# tt0017938                                La glace à trois faces
# tt0035423                                        Kate & Leopold
# tt0036606      Another time, another place - Una storia d'amore
# tt0039442                                         Habla, mudita
# tt0054724                                                Zombie
#
#                             original_title  year date_published  \
# imdb_title_id
# tt0017938           La glace à trois faces  1983     1983-03-13
# tt0035423                   Kate & Leopold  2001     2002-03-01
# tt0036606      Another Time, Another Place  1983     1983-07-15
# tt0039442                    Habla, mudita  1973     1973-06-01
# tt0054724                           Zombie  1971     1971-10-29
#
#                                   genre              country  \
# imdb_title_id
# tt0017938                Drama, Romance               France
# tt0035423      Comedy, Fantasy, Romance                  USA
# tt0036606                    Drama, War                   UK
# tt0039442                         Drama  Spain, West Germany
# tt0054724                        Horror                  USA
#
#                               director  \
# imdb_title_id
# tt0017938                 Jean Epstein
# tt0035423                James Mangold
# tt0036606              Michael Radford
# tt0039442      Manuel Gutiérrez Aragón
# tt0054724                   Del Tenney
#
#                                                           actors  avg_vote  \
# imdb_title_id
# tt0017938      Jeanne Helbling, Suzy Pierson, Olga Day, Raymo...       7.0
# tt0035423      Meg Ryan, Hugh Jackman, Liev Schreiber, Brecki...       6.4
# tt0036606      Phyllis Logan, Giovanni Mauriello, Gianluca Fa...       6.5
# tt0039442      José Luis López Vázquez, Kiti Mánver, Francisc...       6.2
# tt0054724      William Joyce, Heather Hewitt, Walter Coy, Dan...       3.5
#
#                votes usa_gross_income worlwide_gross_income  \
# imdb_title_id
# tt0017938        759              NaN                   NaN
# tt0035423      77852       $ 47121859            $ 76019048
# tt0036606        252              NaN                   NaN
# tt0039442        128              NaN                   NaN
# tt0054724       1214              NaN                   NaN
#
#                reviews_from_users  reviews_from_critics genre_split  \
# imdb_title_id
# tt0017938                     7.0                   4.0       Drama
# tt0035423                   341.0                 115.0      Comedy
# tt0036606                     3.0                  10.0       Drama
# tt0039442                     2.0                   NaN       Drama
# tt0054724                    56.0                  40.0      Horror
#
#               country_split
# imdb_title_id
# tt0017938            France
# tt0035423               USA
# tt0036606                UK
# tt0039442             Spain
# tt0054724               USA

# %%
# Drop the 'country' & 'genre' columns once they're splitted
movies_df_removed_index_1970 = movies_df_removed_index_1970.drop(['country','genre'], axis = 1)
movies_df_removed_index_1970.head()
# Out:
#                                                           title  \
# imdb_title_id
# tt0017938                                La glace à trois faces
# tt0035423                                        Kate & Leopold
# tt0036606      Another time, another place - Una storia d'amore
# tt0039442                                         Habla, mudita
# tt0054724                                                Zombie
#
#                             original_title  year date_published  \
# imdb_title_id
# tt0017938           La glace à trois faces  1983     1983-03-13
# tt0035423                   Kate & Leopold  2001     2002-03-01
# tt0036606      Another Time, Another Place  1983     1983-07-15
# tt0039442                    Habla, mudita  1973     1973-06-01
# tt0054724                           Zombie  1971     1971-10-29
#
#                               director  \
# imdb_title_id
# tt0017938                 Jean Epstein
# tt0035423                James Mangold
# tt0036606              Michael Radford
# tt0039442      Manuel Gutiérrez Aragón
# tt0054724                   Del Tenney
#
#                                                           actors  avg_vote  \
# imdb_title_id
# tt0017938      Jeanne Helbling, Suzy Pierson, Olga Day, Raymo...       7.0
# tt0035423      Meg Ryan, Hugh Jackman, Liev Schreiber, Brecki...       6.4
# tt0036606      Phyllis Logan, Giovanni Mauriello, Gianluca Fa...       6.5
# tt0039442      José Luis López Vázquez, Kiti Mánver, Francisc...       6.2
# tt0054724      William Joyce, Heather Hewitt, Walter Coy, Dan...       3.5
#
#                votes usa_gross_income worlwide_gross_income  \
# imdb_title_id
# tt0017938        759              NaN                   NaN
# tt0035423      77852       $ 47121859            $ 76019048
# tt0036606        252              NaN                   NaN
# tt0039442        128              NaN                   NaN
# tt0054724       1214              NaN                   NaN
#
#                reviews_from_users  reviews_from_critics genre_split  \
# imdb_title_id
# tt0017938                     7.0                   4.0       Drama
# tt0035423                   341.0                 115.0      Comedy
# tt0036606                     3.0                  10.0       Drama
# tt0039442                     2.0                   NaN       Drama
# tt0054724                    56.0                  40.0      Horror
#
#               country_split
# imdb_title_id
# tt0017938            France
# tt0035423               USA
# tt0036606                UK
# tt0039442             Spain
# tt0054724               USA

# %%
movies_df_removed_index_1970["worlwide_gross_income"].value_counts()
# Out:
# $ 8144        13
# $ 509          7
# $ 97182        6
# $ 14000000     5
# $ 2874         5
#               ..
# $ 1094104      1
# $ 954641       1
# $ 58872        1
# $ 39027        1
# $ 34536        1
# Name: worlwide_gross_income, Length: 29840, dtype: int64

# %%
movies_df_removed_index_1970["worlwide_gross_income"].describe()
# Out:
# count      30354
# unique     29840
# top       $ 8144
# freq          13
# Name: worlwide_gross_income, dtype: object

# %%
#movies_df_removed_index_1970["worlwide_gross_income"] = movies_df_removed_index_1970["worlwide_gross_income"].str.startswith("$")
movies_df_removed_index_1970["worlwide_gross_income"] = movies_df_removed_index["worlwide_gross_income"]


movies_df_removed_index_1970.head()
# Out:
#                                                           title  \
# imdb_title_id
# tt0017938                                La glace à trois faces
# tt0035423                                        Kate & Leopold
# tt0036606      Another time, another place - Una storia d'amore
# tt0039442                                         Habla, mudita
# tt0054724                                                Zombie
#
#                             original_title  year date_published  \
# imdb_title_id
# tt0017938           La glace à trois faces  1983     1983-03-13
# tt0035423                   Kate & Leopold  2001     2002-03-01
# tt0036606      Another Time, Another Place  1983     1983-07-15
# tt0039442                    Habla, mudita  1973     1973-06-01
# tt0054724                           Zombie  1971     1971-10-29
#
#                               director  \
# imdb_title_id
# tt0017938                 Jean Epstein
# tt0035423                James Mangold
# tt0036606              Michael Radford
# tt0039442      Manuel Gutiérrez Aragón
# tt0054724                   Del Tenney
#
#                                                           actors  avg_vote  \
# imdb_title_id
# tt0017938      Jeanne Helbling, Suzy Pierson, Olga Day, Raymo...       7.0
# tt0035423      Meg Ryan, Hugh Jackman, Liev Schreiber, Brecki...       6.4
# tt0036606      Phyllis Logan, Giovanni Mauriello, Gianluca Fa...       6.5
# tt0039442      José Luis López Vázquez, Kiti Mánver, Francisc...       6.2
# tt0054724      William Joyce, Heather Hewitt, Walter Coy, Dan...       3.5
#
#                votes usa_gross_income worlwide_gross_income  \
# imdb_title_id
# tt0017938        759              NaN                   NaN
# tt0035423      77852       $ 47121859            $ 76019048
# tt0036606        252              NaN                   NaN
# tt0039442        128              NaN                   NaN
# tt0054724       1214              NaN                   NaN
#
#                reviews_from_users  reviews_from_critics genre_split  \
# imdb_title_id
# tt0017938                     7.0                   4.0       Drama
# tt0035423                   341.0                 115.0      Comedy
# tt0036606                     3.0                  10.0       Drama
# tt0039442                     2.0                   NaN       Drama
# tt0054724                    56.0                  40.0      Horror
#
#               country_split
# imdb_title_id
# tt0017938            France
# tt0035423               USA
# tt0036606                UK
# tt0039442             Spain
# tt0054724               USA

# %%
# converting currencies to USD and then replace NA with average.
def clean_currency(currency: str) -> float:
    try:
        if currency[0].isnumeric():
            try:
                float_value = float(currency)
            except Exception as e:
                print(e)
        else:
            if currency[2].isnumeric():
                float_value = float(currency[2:].replace(',', ''))
            else:
                float_value = float(currency[4:].replace(',', '')) 
    except TypeError:
        float_value = float(currency)
    return float_value

movies_df_removed_index_1970["worlwide_gross_income"] = movies_df_removed_index_1970["worlwide_gross_income"].apply(clean_currency)


#movies_df_removed_index_1970["worlwide_gross_income"] = movies_df_removed_index_1970["worlwide_gross_income"].str.replace(',','').str.replace('$','').astype('float')

movies_df_removed_index_1970["usa_gross_income"] = movies_df_removed_index_1970["usa_gross_income"].apply(clean_currency)

movies_df_removed_index_1970.head()
# Out:
#                                                           title  \
# imdb_title_id
# tt0017938                                La glace à trois faces
# tt0035423                                        Kate & Leopold
# tt0036606      Another time, another place - Una storia d'amore
# tt0039442                                         Habla, mudita
# tt0054724                                                Zombie
#
#                             original_title  year date_published  \
# imdb_title_id
# tt0017938           La glace à trois faces  1983     1983-03-13
# tt0035423                   Kate & Leopold  2001     2002-03-01
# tt0036606      Another Time, Another Place  1983     1983-07-15
# tt0039442                    Habla, mudita  1973     1973-06-01
# tt0054724                           Zombie  1971     1971-10-29
#
#                               director  \
# imdb_title_id
# tt0017938                 Jean Epstein
# tt0035423                James Mangold
# tt0036606              Michael Radford
# tt0039442      Manuel Gutiérrez Aragón
# tt0054724                   Del Tenney
#
#                                                           actors  avg_vote  \
# imdb_title_id
# tt0017938      Jeanne Helbling, Suzy Pierson, Olga Day, Raymo...       7.0
# tt0035423      Meg Ryan, Hugh Jackman, Liev Schreiber, Brecki...       6.4
# tt0036606      Phyllis Logan, Giovanni Mauriello, Gianluca Fa...       6.5
# tt0039442      José Luis López Vázquez, Kiti Mánver, Francisc...       6.2
# tt0054724      William Joyce, Heather Hewitt, Walter Coy, Dan...       3.5
#
#                votes  usa_gross_income  worlwide_gross_income  \
# imdb_title_id
# tt0017938        759               NaN                    NaN
# tt0035423      77852        47121859.0             76019048.0
# tt0036606        252               NaN                    NaN
# tt0039442        128               NaN                    NaN
# tt0054724       1214               NaN                    NaN
#
#                reviews_from_users  reviews_from_critics genre_split  \
# imdb_title_id
# tt0017938                     7.0                   4.0       Drama
# tt0035423                   341.0                 115.0      Comedy
# tt0036606                     3.0                  10.0       Drama
# tt0039442                     2.0                   NaN       Drama
# tt0054724                    56.0                  40.0      Horror
#
#               country_split
# imdb_title_id
# tt0017938            France
# tt0035423               USA
# tt0036606                UK
# tt0039442             Spain
# tt0054724               USA

# %%
# movies_df_removed_index_1970['worlwide_gross_income'] = movies_df_removed_index_1970['worlwide_gross_income'].fillna(movies_df_removed_index_1970['worlwide_gross_income'].mean())

# movies_df_removed_index_1970['usa_gross_income'] = movies_df_removed_index_1970['usa_gross_income'].fillna(movies_df_removed_index_1970['usa_gross_income'].mean())

# movies_df_removed_index_1970["date_published"]

# %%
# Name the Ratings CSV file
ratings_file = pathlib.Path('Resources/IMDb_ratings/IMDB ratings.csv')

# Read and display the Ratings CSV with Pandas
ratings_df = pd.read_csv(ratings_file)
ratings_df.head()
# Out:
#   imdb_title_id  weighted_average_vote  total_votes  mean_vote  median_vote  \
# 0     tt0000009                    5.9          154        5.9          6.0
# 1     tt0000574                    6.1          589        6.3          6.0
# 2     tt0001892                    5.8          188        6.0          6.0
# 3     tt0002101                    5.2          446        5.3          5.0
# 4     tt0002130                    7.0         2237        6.9          7.0
#
#    votes_10  votes_9  votes_8  votes_7  votes_6  ...  females_30age_avg_vote  \
# 0        12        4       10       43       28  ...                     5.7
# 1        57       18       58      137      139  ...                     6.2
# 2         6        6       17       44       52  ...                     5.8
# 3        15        8       16       62       98  ...                     5.5
# 4       210      225      436      641      344  ...                     7.3
#
#    females_30age_votes  females_45age_avg_vote  females_45age_votes  \
# 0                 13.0                     4.5                  4.0
# 1                 23.0                     6.6                 14.0
# 2                  4.0                     6.8                  7.0
# 3                 14.0                     6.1                 21.0
# 4                 82.0                     7.4                 77.0
#
#    top1000_voters_rating  top1000_voters_votes  us_voters_rating  \
# 0                    5.7                  34.0               6.4
# 1                    6.4                  66.0               6.0
# 2                    5.4                  32.0               6.2
# 3                    4.9                  57.0               5.5
# 4                    6.9                 139.0               7.0
#
#    us_voters_votes  non_us_voters_rating  non_us_voters_votes
# 0             51.0                   6.0                 70.0
# 1             96.0                   6.2                331.0
# 2             31.0                   5.9                123.0
# 3            207.0                   4.7                105.0
# 4            488.0                   7.0               1166.0
#
# [5 rows x 49 columns]

# %%
ratings_df.columns
# Out:
# Index(['imdb_title_id', 'weighted_average_vote', 'total_votes', 'mean_vote',
#        'median_vote', 'votes_10', 'votes_9', 'votes_8', 'votes_7', 'votes_6',
#        'votes_5', 'votes_4', 'votes_3', 'votes_2', 'votes_1',
#        'allgenders_0age_avg_vote', 'allgenders_0age_votes',
#        'allgenders_18age_avg_vote', 'allgenders_18age_votes',
#        'allgenders_30age_avg_vote', 'allgenders_30age_votes',
#        'allgenders_45age_avg_vote', 'allgenders_45age_votes',
#        'males_allages_avg_vote', 'males_allages_votes', 'males_0age_avg_vote',
#        'males_0age_votes', 'males_18age_avg_vote', 'males_18age_votes',
#        'males_30age_avg_vote', 'males_30age_votes', 'males_45age_avg_vote',
#        'males_45age_votes', 'females_allages_avg_vote',
#        'females_allages_votes', 'females_0age_avg_vote', 'females_0age_votes',
#        'females_18age_avg_vote', 'females_18age_votes',
#        'females_30age_avg_vote', 'females_30age_votes',
#        'females_45age_avg_vote', 'females_45age_votes',
#        'top1000_voters_rating', 'top1000_voters_votes', 'us_voters_rating',
#        'us_voters_votes', 'non_us_voters_rating', 'non_us_voters_votes'],
#       dtype='object')

# %%
# Drop individual votes
ratings_df_removed = ratings_df.drop(['votes_10', 'votes_9', 'votes_8', 'votes_7', 'votes_6','votes_5', 'votes_4', 'votes_3', 'votes_2', 'votes_1'],axis=1)

ratings_df_removed.columns
# Out:
# Index(['imdb_title_id', 'weighted_average_vote', 'total_votes', 'mean_vote',
#        'median_vote', 'allgenders_0age_avg_vote', 'allgenders_0age_votes',
#        'allgenders_18age_avg_vote', 'allgenders_18age_votes',
#        'allgenders_30age_avg_vote', 'allgenders_30age_votes',
#        'allgenders_45age_avg_vote', 'allgenders_45age_votes',
#        'males_allages_avg_vote', 'males_allages_votes', 'males_0age_avg_vote',
#        'males_0age_votes', 'males_18age_avg_vote', 'males_18age_votes',
#        'males_30age_avg_vote', 'males_30age_votes', 'males_45age_avg_vote',
#        'males_45age_votes', 'females_allages_avg_vote',
#        'females_allages_votes', 'females_0age_avg_vote', 'females_0age_votes',
#        'females_18age_avg_vote', 'females_18age_votes',
#        'females_30age_avg_vote', 'females_30age_votes',
#        'females_45age_avg_vote', 'females_45age_votes',
#        'top1000_voters_rating', 'top1000_voters_votes', 'us_voters_rating',
#        'us_voters_votes', 'non_us_voters_rating', 'non_us_voters_votes'],
#       dtype='object')

# %%
# Sum all 'males' and 'females' votes, group them separately by genders.
ratings_df_clean = ratings_df_removed.copy(deep=True)
for group in ['males', 'females']:
    columns_to_sum = [column
        for column in ratings_df_clean.columns
             if (column.startswith(group)) and ('avg' not in column)]
    ratings_df_clean[group] = ratings_df_clean[columns_to_sum].sum(axis=1)
    
    columns_to_drop = [column
        for column in ratings_df_clean.columns
             if (column.startswith(group)) and ('avg' in column)] + columns_to_sum
#     print(columns_to_drop)
    ratings_df_clean = ratings_df_clean.drop(columns_to_drop, axis=1)

ratings_df_clean.columns
# Out:
# Index(['imdb_title_id', 'weighted_average_vote', 'total_votes', 'mean_vote',
#        'median_vote', 'allgenders_0age_avg_vote', 'allgenders_0age_votes',
#        'allgenders_18age_avg_vote', 'allgenders_18age_votes',
#        'allgenders_30age_avg_vote', 'allgenders_30age_votes',
#        'allgenders_45age_avg_vote', 'allgenders_45age_votes',
#        'top1000_voters_rating', 'top1000_voters_votes', 'us_voters_rating',
#        'us_voters_votes', 'non_us_voters_rating', 'non_us_voters_votes',
#        'males', 'females'],
#       dtype='object')

# %%
# Reset index to 'imdb_title_id'
ratings_df_clean_index = ratings_df_clean.set_index('imdb_title_id')

# %%
# Merge the Movies data frame and the Ratings data frame
merged_df = movies_df_removed_index_1970.merge(ratings_df_clean_index, on='imdb_title_id')

merged_df.head()
# Out:
#                                                           title  \
# imdb_title_id
# tt0017938                                La glace à trois faces
# tt0035423                                        Kate & Leopold
# tt0036606      Another time, another place - Una storia d'amore
# tt0039442                                         Habla, mudita
# tt0054724                                                Zombie
#
#                             original_title  year date_published  \
# imdb_title_id
# tt0017938           La glace à trois faces  1983     1983-03-13
# tt0035423                   Kate & Leopold  2001     2002-03-01
# tt0036606      Another Time, Another Place  1983     1983-07-15
# tt0039442                    Habla, mudita  1973     1973-06-01
# tt0054724                           Zombie  1971     1971-10-29
#
#                               director  \
# imdb_title_id
# tt0017938                 Jean Epstein
# tt0035423                James Mangold
# tt0036606              Michael Radford
# tt0039442      Manuel Gutiérrez Aragón
# tt0054724                   Del Tenney
#
#                                                           actors  avg_vote  \
# imdb_title_id
# tt0017938      Jeanne Helbling, Suzy Pierson, Olga Day, Raymo...       7.0
# tt0035423      Meg Ryan, Hugh Jackman, Liev Schreiber, Brecki...       6.4
# tt0036606      Phyllis Logan, Giovanni Mauriello, Gianluca Fa...       6.5
# tt0039442      José Luis López Vázquez, Kiti Mánver, Francisc...       6.2
# tt0054724      William Joyce, Heather Hewitt, Walter Coy, Dan...       3.5
#
#                votes  usa_gross_income  worlwide_gross_income  ...  \
# imdb_title_id                                                  ...
# tt0017938        759               NaN                    NaN  ...
# tt0035423      77852        47121859.0             76019048.0  ...
# tt0036606        252               NaN                    NaN  ...
# tt0039442        128               NaN                    NaN  ...
# tt0054724       1214               NaN                    NaN  ...
#
#                allgenders_45age_avg_vote  allgenders_45age_votes  \
# imdb_title_id
# tt0017938                            6.9                   206.0
# tt0035423                            6.4                 12104.0
# tt0036606                            6.6                   138.0
# tt0039442                            5.1                    56.0
# tt0054724                            3.5                   457.0
#
#               top1000_voters_rating top1000_voters_votes  us_voters_rating  \
# imdb_title_id
# tt0017938                       6.2                 77.0               6.9
# tt0035423                       6.1                468.0               6.4
# tt0036606                       6.2                 30.0               6.7
# tt0039442                       4.1                 15.0               6.0
# tt0054724                       3.0                 94.0               3.6
#
#                us_voters_votes  non_us_voters_rating  non_us_voters_votes  \
# imdb_title_id
# tt0017938                184.0                   7.0                411.0
# tt0035423              14831.0                   6.3              38534.0
# tt0036606                 53.0                   6.6                125.0
# tt0039442                  3.0                   5.6                 75.0
# tt0054724                591.0                   3.3                350.0
#
#                  males  females
# imdb_title_id
# tt0017938       1096.0    170.0
# tt0035423      69268.0  53551.0
# tt0036606        322.0     54.0
# tt0039442        151.0     47.0
# tt0054724       1750.0    215.0
#
# [5 rows x 34 columns]

# %%
merged_df.columns
# Out:
# Index(['title', 'original_title', 'year', 'date_published', 'director',
#        'actors', 'avg_vote', 'votes', 'usa_gross_income',
#        'worlwide_gross_income', 'reviews_from_users', 'reviews_from_critics',
#        'genre_split', 'country_split', 'weighted_average_vote', 'total_votes',
#        'mean_vote', 'median_vote', 'allgenders_0age_avg_vote',
#        'allgenders_0age_votes', 'allgenders_18age_avg_vote',
#        'allgenders_18age_votes', 'allgenders_30age_avg_vote',
#        'allgenders_30age_votes', 'allgenders_45age_avg_vote',
#        'allgenders_45age_votes', 'top1000_voters_rating',
#        'top1000_voters_votes', 'us_voters_rating', 'us_voters_votes',
#        'non_us_voters_rating', 'non_us_voters_votes', 'males', 'females'],
#       dtype='object')

# %% [markdown]
# # The processes below are to analyze the relationship between movie ratings and award winnings/nominations.

# %%
# Import the OSCAR award file
oscar_file = pathlib.Path('Resources/oscar_awards/the_oscar_award.csv')
oscar_df = pd.read_csv(oscar_file)
oscar_df.head()
# Out:
#    year_film  year_ceremony  ceremony category                 name  \
# 0       1927           1928         1    ACTOR  Richard Barthelmess
# 1       1927           1928         1    ACTOR        Emil Jannings
# 2       1927           1928         1  ACTRESS       Louise Dresser
# 3       1927           1928         1  ACTRESS         Janet Gaynor
# 4       1927           1928         1  ACTRESS       Gloria Swanson
#
#                film  winner
# 0         The Noose   False
# 1  The Last Command    True
# 2   A Ship Comes In   False
# 3        7th Heaven    True
# 4    Sadie Thompson   False

# %%
# Filter the Oscar list based on years range from 1970 to 2020. 
oscar_df_filtered = oscar_df[(oscar_df['year_film']>=1970)]
oscar_df_filtered
# Out:
#        year_film  year_ceremony  ceremony                          category  \
# 4773        1970           1971        43                             ACTOR
# 4774        1970           1971        43                             ACTOR
# 4775        1970           1971        43                             ACTOR
# 4776        1970           1971        43                             ACTOR
# 4777        1970           1971        43                             ACTOR
# ...          ...            ...       ...                               ...
# 10390       2019           2020        92     WRITING (Original Screenplay)
# 10391       2019           2020        92  JEAN HERSHOLT HUMANITARIAN AWARD
# 10392       2019           2020        92                    HONORARY AWARD
# 10393       2019           2020        92                    HONORARY AWARD
# 10394       2019           2020        92                    HONORARY AWARD
#
#                                                     name  \
# 4773                                      Melvyn Douglas
# 4774                                    James Earl Jones
# 4775                                      Jack Nicholson
# 4776                                         Ryan O'Neal
# 4777                                     George C. Scott
# ...                                                  ...
# 10390  Screenplay by Bong Joon Ho, Han Jin Won; Story...
# 10391                                        Geena Davis
# 10392                                        David Lynch
# 10393                                          Wes Studi
# 10394                                    Lina Wertmüller
#
#                              film  winner
# 4773   I Never Sang for My Father   False
# 4774         The Great White Hope   False
# 4775             Five Easy Pieces   False
# 4776                   Love Story   False
# 4777                       Patton    True
# ...                           ...     ...
# 10390                    Parasite    True
# 10391                         NaN    True
# 10392                         NaN    True
# 10393                         NaN    True
# 10394                         NaN    True
#
# [5622 rows x 7 columns]

# %%
# Drop the rows without values
oscar_df_filtered = oscar_df_filtered.dropna()


# Drop the duplicate film names to obtain a list of unique films, then drop the unecessary columns and reset the index.

oscar_unique_films = oscar_df_filtered.drop_duplicates(subset=['film'])
oscar_films_df = oscar_unique_films.drop(columns=['year_ceremony','ceremony','category', 'name', 'winner'])
oscar_films_df = oscar_films_df.rename(columns={'year_film':'year'})
oscar_films_df = oscar_films_df.reset_index(drop=True)

# Add a column to the oscar_films_df to indicate that all movies in this data frame were either won or nominated by the Oscar Academy.

for i, row in oscar_films_df.iterrows():
    
    oscar_films_df.at[i,'oscar_win/nominated'] = True

oscar_films_df
# Out:
#       year                        film oscar_win/nominated
# 0     1970  I Never Sang for My Father                True
# 1     1970        The Great White Hope                True
# 2     1970            Five Easy Pieces                True
# 3     1970                  Love Story                True
# 4     1970                      Patton                True
# ...    ...                         ...                 ...
# 2621  2019                       Saria                True
# 2622  2019                    A Sister                True
# 2623  2019                    Ad Astra                True
# 2624  2019           Avengers: Endgame                True
# 2625  2019                  Knives Out                True
#
# [2626 rows x 3 columns]

# %%
# Reformat the films' names to keep ONLY the letters and numbers to eliminate whitespaces and other symbols. Name the new column as 'title_formatted'.

for i, row in oscar_films_df.iterrows():

    filmname = re.sub('[\W_]+', '', row['film'])
    oscar_films_df.at[i,'title_formatted'] = filmname

oscar_films_df
# Out:
#       year                        film oscar_win/nominated  \
# 0     1970  I Never Sang for My Father                True
# 1     1970        The Great White Hope                True
# 2     1970            Five Easy Pieces                True
# 3     1970                  Love Story                True
# 4     1970                      Patton                True
# ...    ...                         ...                 ...
# 2621  2019                       Saria                True
# 2622  2019                    A Sister                True
# 2623  2019                    Ad Astra                True
# 2624  2019           Avengers: Endgame                True
# 2625  2019                  Knives Out                True
#
#             title_formatted
# 0     INeverSangforMyFather
# 1         TheGreatWhiteHope
# 2            FiveEasyPieces
# 3                 LoveStory
# 4                    Patton
# ...                     ...
# 2621                  Saria
# 2622                ASister
# 2623                AdAstra
# 2624        AvengersEndgame
# 2625              KnivesOut
#
# [2626 rows x 4 columns]

# %%
# merged_df.head()

# %%
# In the previously merged movies&ratings data frame, also reformat the movie titles to keep ONLY the letters and numbers, eliminate whitespaces and other symbols.
merged_df_copy = merged_df
for i, row in merged_df_copy.iterrows():
    titlename = re.sub('[\W_]+', '', row['title'])
    merged_df_copy.at[i,'title_formatted'] = titlename

merged_df_copy

merged_df_copy.columns
# Out:
# Index(['title', 'original_title', 'year', 'date_published', 'director',
#        'actors', 'avg_vote', 'votes', 'usa_gross_income',
#        'worlwide_gross_income', 'reviews_from_users', 'reviews_from_critics',
#        'genre_split', 'country_split', 'weighted_average_vote', 'total_votes',
#        'mean_vote', 'median_vote', 'allgenders_0age_avg_vote',
#        'allgenders_0age_votes', 'allgenders_18age_avg_vote',
#        'allgenders_18age_votes', 'allgenders_30age_avg_vote',
#        'allgenders_30age_votes', 'allgenders_45age_avg_vote',
#        'allgenders_45age_votes', 'top1000_voters_rating',
#        'top1000_voters_votes', 'us_voters_rating', 'us_voters_votes',
#        'non_us_voters_rating', 'non_us_voters_votes', 'males', 'females',
#        'title_formatted'],
#       dtype='object')

# %%
# Drop the unnecessary columns to obtain a list with ONLY the movie names and ratings.
movies_list = merged_df_copy[['year','title', 'title_formatted', 'weighted_average_vote']]
movies_list
# Out:
#                year                                             title  \
# imdb_title_id
# tt0017938      1983                            La glace à trois faces
# tt0035423      2001                                    Kate & Leopold
# tt0036606      1983  Another time, another place - Una storia d'amore
# tt0039442      1973                                     Habla, mudita
# tt0054724      1971                                            Zombie
# ...             ...                                               ...
# tt9908390      2020                                           Le lion
# tt9911196      2020                    De Beentjes van Sint-Hildegard
# tt9911774      2019                         Padmavyuhathile Abhimanyu
# tt9914286      2019                                 Sokagin Çocuklari
# tt9914942      2019                        La vida sense la Sara Amat
#
#                                       title_formatted  weighted_average_vote
# imdb_title_id
# tt0017938                          Laglaceàtroisfaces                    7.0
# tt0035423                                 KateLeopold                    6.4
# tt0036606      AnothertimeanotherplaceUnastoriadamore                    6.5
# tt0039442                                 Hablamudita                    6.2
# tt0054724                                      Zombie                    3.5
# ...                                               ...                    ...
# tt9908390                                      Lelion                    5.3
# tt9911196                  DeBeentjesvanSintHildegard                    7.7
# tt9911774                    PadmavyuhathileAbhimanyu                    7.9
# tt9914286                            SokaginÇocuklari                    6.4
# tt9914942                       LavidasenselaSaraAmat                    6.7
#
# [70264 rows x 4 columns]

# %%
# Merge the movies_list with oscar_films_df on 'title_formatted'. In this merged data frame, we should be able to see all movie data plus the indication of which movies have won or been nominated in Oscar.
award_list = pd.merge(movies_list, oscar_films_df, how='left', on=['title_formatted','year'])

# Fill the non-winning/non-nominated movies with 'False'
award_list['oscar_win/nominated'] = award_list['oscar_win/nominated'].fillna(False)
award_list = award_list.drop(columns=['film'])
award_list
# Out:
#        year                                             title  \
# 0      1983                            La glace à trois faces
# 1      2001                                    Kate & Leopold
# 2      1983  Another time, another place - Una storia d'amore
# 3      1973                                     Habla, mudita
# 4      1971                                            Zombie
# ...     ...                                               ...
# 70259  2020                                           Le lion
# 70260  2020                    De Beentjes van Sint-Hildegard
# 70261  2019                         Padmavyuhathile Abhimanyu
# 70262  2019                                 Sokagin Çocuklari
# 70263  2019                        La vida sense la Sara Amat
#
#                               title_formatted  weighted_average_vote  \
# 0                          Laglaceàtroisfaces                    7.0
# 1                                 KateLeopold                    6.4
# 2      AnothertimeanotherplaceUnastoriadamore                    6.5
# 3                                 Hablamudita                    6.2
# 4                                      Zombie                    3.5
# ...                                       ...                    ...
# 70259                                  Lelion                    5.3
# 70260              DeBeentjesvanSintHildegard                    7.7
# 70261                PadmavyuhathileAbhimanyu                    7.9
# 70262                        SokaginÇocuklari                    6.4
# 70263                   LavidasenselaSaraAmat                    6.7
#
#        oscar_win/nominated
# 0                    False
# 1                     True
# 2                    False
# 3                    False
# 4                    False
# ...                    ...
# 70259                False
# 70260                False
# 70261                False
# 70262                False
# 70263                False
#
# [70264 rows x 5 columns]

# %%
# award_list.loc[award_list['oscar_win/nominated']==True]
# award_list.loc[award_list['title']=='Joker']

# %%
# Create the bins in which Moving Ratings Data will be held
ratings_to_cut = [0, 1.9, 3.9, 5.9, 7.9, 10]
# Create the names for the bins
ratings_group_name = ['<2', '2-4', '4-6', '6-8', '8-10']

# Create rating groups using the dataset with non-duplicate players
ratings_groups = pd.cut(
    x=award_list['weighted_average_vote'],
    bins=ratings_to_cut,
    labels=ratings_group_name,
    include_lowest=True,
)


# Create data frame to show whether movies with higher ratings tend to receive more awards.

oscar_count = award_list.groupby(ratings_groups)['oscar_win/nominated'].sum()

oscar_n_rating = {
    'Oscar Count': oscar_count
}

oscar_by_rating = pd.DataFrame(oscar_n_rating)
oscar_by_rating
# Out:
#                        Oscar Count
# weighted_average_vote
# <2                               0
# 2-4                              1
# 4-6                             18
# 6-8                            402
# 8-10                            66

# %%
# Plot a bar chart to plot the relationship between the Oscar winning/nominated movies percentages by ratings intervals

# Set x-axis and y-axis for Oscar winning/nominated movies by ratings intervals
rating_intervals = np.arange(len(ratings_group_name))
oscar_count_by_interval = oscar_count.tolist()

# Set up the graph size and tick labels
plt.subplots(figsize=(12,8))
interval_names = ratings_group_name
xtick_location = [value for value in rating_intervals] 
plt.xticks(xtick_location, interval_names)

# Plot the bar chart and style the chart 
plt.bar(rating_intervals,
        oscar_count_by_interval,
        width=0.5,
        align='center')
plt.xlim(-0.5, len(rating_intervals)-0.5)
plt.title('Oscar Winnings/Nominations by Ratings Intervals')
plt.xlabel('IMDB Ratings Intervals')
plt.ylabel('Number of Oscar Wins/Nominations')
plt.show()

# %% [markdown]
# ## Based on the ratings intervals, further analyze the number of USA movies within each interval.

# %%
# Drop the unnecessary columns to obtain a list with ONLY the movie names and ratings.
movies_country = merged_df_copy[['year','title', 'title_formatted', 'country_split']]
movies_country
# Out:
#                year                                             title  \
# imdb_title_id
# tt0017938      1983                            La glace à trois faces
# tt0035423      2001                                    Kate & Leopold
# tt0036606      1983  Another time, another place - Una storia d'amore
# tt0039442      1973                                     Habla, mudita
# tt0054724      1971                                            Zombie
# ...             ...                                               ...
# tt9908390      2020                                           Le lion
# tt9911196      2020                    De Beentjes van Sint-Hildegard
# tt9911774      2019                         Padmavyuhathile Abhimanyu
# tt9914286      2019                                 Sokagin Çocuklari
# tt9914942      2019                        La vida sense la Sara Amat
#
#                                       title_formatted country_split
# imdb_title_id
# tt0017938                          Laglaceàtroisfaces        France
# tt0035423                                 KateLeopold           USA
# tt0036606      AnothertimeanotherplaceUnastoriadamore            UK
# tt0039442                                 Hablamudita         Spain
# tt0054724                                      Zombie           USA
# ...                                               ...           ...
# tt9908390                                      Lelion        France
# tt9911196                  DeBeentjesvanSintHildegard   Netherlands
# tt9911774                    PadmavyuhathileAbhimanyu         India
# tt9914286                            SokaginÇocuklari        Turkey
# tt9914942                       LavidasenselaSaraAmat         Spain
#
# [70264 rows x 4 columns]

# %%
# Merge the movies_list with oscar_films_df on 'title_formatted'. In this merged data frame, we should be able to see all movie data plus the indication of which movies have won or been nominated in Oscar.
award_country = pd.merge(movies_country, oscar_films_df, how='left', on=['title_formatted','year'])

# Fill the non-winning/non-nominated movies with 'False'
award_country['oscar_win/nominated'] = award_list['oscar_win/nominated'].fillna(False)
award_country = award_country.drop(columns=['film'])
award_country
# Out:
#        year                                             title  \
# 0      1983                            La glace à trois faces
# 1      2001                                    Kate & Leopold
# 2      1983  Another time, another place - Una storia d'amore
# 3      1973                                     Habla, mudita
# 4      1971                                            Zombie
# ...     ...                                               ...
# 70259  2020                                           Le lion
# 70260  2020                    De Beentjes van Sint-Hildegard
# 70261  2019                         Padmavyuhathile Abhimanyu
# 70262  2019                                 Sokagin Çocuklari
# 70263  2019                        La vida sense la Sara Amat
#
#                               title_formatted country_split  \
# 0                          Laglaceàtroisfaces        France
# 1                                 KateLeopold           USA
# 2      AnothertimeanotherplaceUnastoriadamore            UK
# 3                                 Hablamudita         Spain
# 4                                      Zombie           USA
# ...                                       ...           ...
# 70259                                  Lelion        France
# 70260              DeBeentjesvanSintHildegard   Netherlands
# 70261                PadmavyuhathileAbhimanyu         India
# 70262                        SokaginÇocuklari        Turkey
# 70263                   LavidasenselaSaraAmat         Spain
#
#        oscar_win/nominated
# 0                    False
# 1                     True
# 2                    False
# 3                    False
# 4                    False
# ...                    ...
# 70259                False
# 70260                False
# 70261                False
# 70262                False
# 70263                False
#
# [70264 rows x 5 columns]

# %%
# country_df = award_country.set_index('country_split')
# Create the bins in which Moving Ratings Data will be held
ratings_to_cut = [0, 1.9, 3.9, 5.9, 7.9, 10]
# Create the names for the bins
ratings_group_name = ['<2', '2-4', '4-6', '6-8', '8-10']

# Create rating groups using the dataset with non-duplicate players
ratings_groups = pd.cut(
    x=award_list['weighted_average_vote'],
    bins=ratings_to_cut,
    labels=ratings_group_name,
    include_lowest=True,
)


# Create data frame to show whether movies with higher ratings tend to receive more awards.

oscar_country = award_country.groupby([ratings_groups, 'country_split']).size()


oscar_n_country = {
    'Oscar Count': oscar_country
}

pd.set_option('display.max_rows', 1000)
oscar_by_country = pd.DataFrame(oscar_n_country)
# oscar_by_country

# %%
award_country.groupby(ratings_groups)['country_split'].count()
# Out:
# weighted_average_vote
# <2        361
# 2-4      6277
# 4-6     27638
# 6-8     34547
# 8-10     1378
# Name: country_split, dtype: int64

# %%
# Plot a bar chart to plot the relationship between the USA movies percentages by ratings intervals

# Set x-axis and y-axis for USA movies by ratings intervals
rating_intervals = np.arange(len(ratings_group_name))
usa_movies = [172,3451,10887,7540,218]
usa_movies_total = (award_country.groupby(ratings_groups)['country_split'].count()).tolist()
usa_movies_pct = [a / b for a, b in zip(usa_movies, usa_movies_total)]

# Set up the graph size and tick labels
plt.subplots(figsize=(12,8))
interval_names = ratings_group_name
xtick_location = [value for value in rating_intervals] 
plt.xticks(xtick_location, interval_names)

# Plot the bar chart and style the chart
plt.bar(rating_intervals,
        usa_movies_pct,
        width=0.5,
        align='center')
plt.xlim(-0.5, len(rating_intervals)-0.5)
plt.ylim(0, max(usa_movies_pct)+.1)
plt.title('USA Movies % by Ratings Intervals')
plt.xlabel('IMDB Ratings Intervals')
plt.ylabel('Percentage of USA Movies')
plt.show()

# %% [markdown]
# ## Think about possible explanation of why highest ratings does NOT necessarily result in highest award winnings/nominations.
# * Assumption One -> A lot of Oscar winnings/nominations (i.e., Art Direction, Costume Design, Make-up & Styling, etc.) are given to non-high-rating movies (aka, falls into the range of 6-8). These could take up the majority of the Oscar counts in our dataset.
# * Assumption Two -> Assuming Oscar nominations are biased because they tend to favor the U.S. produced movies. However, based on our analysis, the least percent of USA movies falls into the 8-10 range.
# * Based on Assumption Two, the reason could be:
# *    1. Oscar does prefer higher-rated movies, that's why most of the winning/nominated movies are in the 6-8 & 8-10 ranges.
# *    2. The reason why 8-10 range movies does not have highest award counts is because the population of USA movies in 8-10 rating range is too small.

# %% [markdown]
# # The processes below are to analyze the relationship between movie genres and award winnings/nominations.

# %%
# Apply the same methodology as the previous ratings vs. award analysis.
# Drop the unnecessary columns to obtain a list with ONLY the movie names and ratings.
movies_genres = merged_df_copy[['year','title', 'title_formatted', 'genre_split']]
movies_genres
# Out:
#                year                                             title  \
# imdb_title_id
# tt0017938      1983                            La glace à trois faces
# tt0035423      2001                                    Kate & Leopold
# tt0036606      1983  Another time, another place - Una storia d'amore
# tt0039442      1973                                     Habla, mudita
# tt0054724      1971                                            Zombie
# ...             ...                                               ...
# tt9908390      2020                                           Le lion
# tt9911196      2020                    De Beentjes van Sint-Hildegard
# tt9911774      2019                         Padmavyuhathile Abhimanyu
# tt9914286      2019                                 Sokagin Çocuklari
# tt9914942      2019                        La vida sense la Sara Amat
#
#                                       title_formatted genre_split
# imdb_title_id
# tt0017938                          Laglaceàtroisfaces       Drama
# tt0035423                                 KateLeopold      Comedy
# tt0036606      AnothertimeanotherplaceUnastoriadamore       Drama
# tt0039442                                 Hablamudita       Drama
# tt0054724                                      Zombie      Horror
# ...                                               ...         ...
# tt9908390                                      Lelion      Comedy
# tt9911196                  DeBeentjesvanSintHildegard      Comedy
# tt9911774                    PadmavyuhathileAbhimanyu       Drama
# tt9914286                            SokaginÇocuklari       Drama
# tt9914942                       LavidasenselaSaraAmat       Drama
#
# [70264 rows x 4 columns]

# %%
# Merge the movies_list with oscar_films_df on 'title_formatted'. In this merged data frame, we should be able to see all movie data plus the indication of which movies have won or been nominated in Oscar.
award_list_2 = pd.merge(movies_genres, oscar_films_df, how='left', on=['title_formatted','year'])

# Fill the non-winning/non-nominated movies with 'False'
award_list_2['oscar_win/nominated'] = award_list_2['oscar_win/nominated'].fillna(False)
award_list_2 = award_list_2.drop(columns=['film'])
award_list_2
# Out:
#        year                                             title  \
# 0      1983                            La glace à trois faces
# 1      2001                                    Kate & Leopold
# 2      1983  Another time, another place - Una storia d'amore
# 3      1973                                     Habla, mudita
# 4      1971                                            Zombie
# ...     ...                                               ...
# 70259  2020                                           Le lion
# 70260  2020                    De Beentjes van Sint-Hildegard
# 70261  2019                         Padmavyuhathile Abhimanyu
# 70262  2019                                 Sokagin Çocuklari
# 70263  2019                        La vida sense la Sara Amat
#
#                               title_formatted genre_split  oscar_win/nominated
# 0                          Laglaceàtroisfaces       Drama                False
# 1                                 KateLeopold      Comedy                 True
# 2      AnothertimeanotherplaceUnastoriadamore       Drama                False
# 3                                 Hablamudita       Drama                False
# 4                                      Zombie      Horror                False
# ...                                       ...         ...                  ...
# 70259                                  Lelion      Comedy                False
# 70260              DeBeentjesvanSintHildegard      Comedy                False
# 70261                PadmavyuhathileAbhimanyu       Drama                False
# 70262                        SokaginÇocuklari       Drama                False
# 70263                   LavidasenselaSaraAmat       Drama                False
#
# [70264 rows x 5 columns]

# %%
# Create data frame to determine if there's any relationship between movie genres and awards.

genre_awards = award_list_2.groupby(['genre_split'])['oscar_win/nominated'].sum()

award_by_genre = pd.DataFrame(genre_awards)
award_by_genre = award_by_genre.sort_values('oscar_win/nominated', ascending=False)
award_by_genre
# Out:
#              oscar_win/nominated
# genre_split
# Drama                        144
# Action                        90
# Biography                     84
# Comedy                        72
# Animation                     36
# Crime                         34
# Adventure                     22
# Fantasy                        2
# Romance                        2
# Horror                         1
# Mystery                        0
# War                            0
# Thriller                       0
# Sport                          0
# Sci-Fi                         0
# History                        0
# Musical                        0
# Music                          0
# Adult                          0
# Family                         0
# Documentary                    0
# Western                        0

# %%
# Generate a line plot of genre versus oscar award counts 

# Set up x-axis & y-axis variable
genre_x_axis = (award_list_2['genre_split'].drop_duplicates()).tolist()
genre_y_axis = award_by_genre['oscar_win/nominated']


# Plot the line chart
plt.subplots(figsize=(12,8))
plt.xticks(rotation='vertical')

plt.plot(genre_x_axis,
         genre_y_axis)
plt.xlabel('Genres')
plt.ylabel('Number of Oscar Wins/Nominations')
plt.title('Oscar Favored Movie Genres')
plt.show()

# %% [markdown]
# # The processes below are to analyze the relationship between movie directors and award winnings/nominations.

# %%
# split directors, actors/actresses by comma delimiter and select first word

director_split = merged_df_copy["director"].str.split(",", n=1, expand = True)
merged_df_copy["director_split"] = director_split[0]

actor_split = merged_df_copy["actors"].str.split(",", n=1, expand = True)
merged_df_copy["actor_split"] = actor_split[0]

merged_df_copy.columns
# Out:
# Index(['title', 'original_title', 'year', 'date_published', 'director',
#        'actors', 'avg_vote', 'votes', 'usa_gross_income',
#        'worlwide_gross_income', 'reviews_from_users', 'reviews_from_critics',
#        'genre_split', 'country_split', 'weighted_average_vote', 'total_votes',
#        'mean_vote', 'median_vote', 'allgenders_0age_avg_vote',
#        'allgenders_0age_votes', 'allgenders_18age_avg_vote',
#        'allgenders_18age_votes', 'allgenders_30age_avg_vote',
#        'allgenders_30age_votes', 'allgenders_45age_avg_vote',
#        'allgenders_45age_votes', 'top1000_voters_rating',
#        'top1000_voters_votes', 'us_voters_rating', 'us_voters_votes',
#        'non_us_voters_rating', 'non_us_voters_votes', 'males', 'females',
#        'title_formatted', 'director_split', 'actor_split'],
#       dtype='object')

# %%
# Apply the same methodology as the previous analyses.

# Drop the unnecessary columns to obtain a list with ONLY the movie names and ratings.
movies_directors = merged_df_copy[['year','title', 'title_formatted', 'director_split']]
movies_directors
# Out:
#                year                                             title  \
# imdb_title_id
# tt0017938      1983                            La glace à trois faces
# tt0035423      2001                                    Kate & Leopold
# tt0036606      1983  Another time, another place - Una storia d'amore
# tt0039442      1973                                     Habla, mudita
# tt0054724      1971                                            Zombie
# ...             ...                                               ...
# tt9908390      2020                                           Le lion
# tt9911196      2020                    De Beentjes van Sint-Hildegard
# tt9911774      2019                         Padmavyuhathile Abhimanyu
# tt9914286      2019                                 Sokagin Çocuklari
# tt9914942      2019                        La vida sense la Sara Amat
#
#                                       title_formatted           director_split
# imdb_title_id
# tt0017938                          Laglaceàtroisfaces             Jean Epstein
# tt0035423                                 KateLeopold            James Mangold
# tt0036606      AnothertimeanotherplaceUnastoriadamore          Michael Radford
# tt0039442                                 Hablamudita  Manuel Gutiérrez Aragón
# tt0054724                                      Zombie               Del Tenney
# ...                                               ...                      ...
# tt9908390                                      Lelion   Ludovic Colbeau-Justin
# tt9911196                  DeBeentjesvanSintHildegard          Johan Nijenhuis
# tt9911774                    PadmavyuhathileAbhimanyu          Vineesh Aaradya
# tt9914286                            SokaginÇocuklari        Ahmet Faik Akinci
# tt9914942                       LavidasenselaSaraAmat                Laura Jou
#
# [70264 rows x 4 columns]

# %%
# Merge the movies_list with oscar_films_df on 'title_formatted'. In this merged data frame, we should be able to see all movie data plus the indication of which movies have won or been nominated in Oscar.
award_list_3 = pd.merge(movies_directors, oscar_films_df, how='left', on=['title_formatted','year'])

# Fill the non-winning/non-nominated movies with 'False'
award_list_3['oscar_win/nominated'] = award_list_3['oscar_win/nominated'].fillna(False)
award_list_3 = award_list_3.drop(columns=['film'])
award_list_3
# Out:
#        year                                             title  \
# 0      1983                            La glace à trois faces
# 1      2001                                    Kate & Leopold
# 2      1983  Another time, another place - Una storia d'amore
# 3      1973                                     Habla, mudita
# 4      1971                                            Zombie
# ...     ...                                               ...
# 70259  2020                                           Le lion
# 70260  2020                    De Beentjes van Sint-Hildegard
# 70261  2019                         Padmavyuhathile Abhimanyu
# 70262  2019                                 Sokagin Çocuklari
# 70263  2019                        La vida sense la Sara Amat
#
#                               title_formatted           director_split  \
# 0                          Laglaceàtroisfaces             Jean Epstein
# 1                                 KateLeopold            James Mangold
# 2      AnothertimeanotherplaceUnastoriadamore          Michael Radford
# 3                                 Hablamudita  Manuel Gutiérrez Aragón
# 4                                      Zombie               Del Tenney
# ...                                       ...                      ...
# 70259                                  Lelion   Ludovic Colbeau-Justin
# 70260              DeBeentjesvanSintHildegard          Johan Nijenhuis
# 70261                PadmavyuhathileAbhimanyu          Vineesh Aaradya
# 70262                        SokaginÇocuklari        Ahmet Faik Akinci
# 70263                   LavidasenselaSaraAmat                Laura Jou
#
#        oscar_win/nominated
# 0                    False
# 1                     True
# 2                    False
# 3                    False
# 4                    False
# ...                    ...
# 70259                False
# 70260                False
# 70261                False
# 70262                False
# 70263                False
#
# [70264 rows x 5 columns]

# %%
# Create data frame to determine if there's any relationship between movie directors and awards.

director_awards = award_list_3.groupby(['director_split'])['oscar_win/nominated'].sum()

award_by_director = pd.DataFrame(director_awards)
award_by_director = award_by_director.sort_values('oscar_win/nominated', ascending=False)
award_by_director_top = award_by_director.head(15)
award_by_director_top
# Out:
#                    oscar_win/nominated
# director_split
# Clint Eastwood                      10
# Woody Allen                         10
# Steven Spielberg                     9
# Martin Scorsese                      7
# Ridley Scott                         5
# Sam Mendes                           5
# Christopher Nolan                    5
# James Cameron                        4
# Tim Burton                           4
# Michael Bay                          4
# Denis Villeneuve                     4
# Barry Levinson                       4
# Ron Howard                           4
# Quentin Tarantino                    4
# Wolfgang Petersen                    3

# %%
# Generate a line plot of movie directors versus oscar award counts 

# Set up x-axis & y-axis variable
director_x_axis = award_by_director_top['oscar_win/nominated'].index.tolist()
director_y_axis = award_by_director_top['oscar_win/nominated']


# Plot the line chart
plt.subplots(figsize=(12,8))
plt.xticks(rotation='vertical')

plt.plot(director_x_axis,
         director_y_axis)
plt.xlabel('Movie Directors')
plt.ylabel('Number of Oscar Wins/Nominations')
plt.title('Oscar Favored Movie Directors')
plt.show()

# %% [markdown]
# # The processes below are to analyze the relationship between movie actors/actresses and award winnings/nominations.

# %%
# Apply the same methodology as the previous analyses.

# Drop the unnecessary columns to obtain a list with ONLY the movie names and ratings.
movies_actors = merged_df_copy[['year','title', 'title_formatted', 'actor_split']]
movies_actors
# Out:
#                year                                             title  \
# imdb_title_id
# tt0017938      1983                            La glace à trois faces
# tt0035423      2001                                    Kate & Leopold
# tt0036606      1983  Another time, another place - Una storia d'amore
# tt0039442      1973                                     Habla, mudita
# tt0054724      1971                                            Zombie
# ...             ...                                               ...
# tt9908390      2020                                           Le lion
# tt9911196      2020                    De Beentjes van Sint-Hildegard
# tt9911774      2019                         Padmavyuhathile Abhimanyu
# tt9914286      2019                                 Sokagin Çocuklari
# tt9914942      2019                        La vida sense la Sara Amat
#
#                                       title_formatted              actor_split
# imdb_title_id
# tt0017938                          Laglaceàtroisfaces          Jeanne Helbling
# tt0035423                                 KateLeopold                 Meg Ryan
# tt0036606      AnothertimeanotherplaceUnastoriadamore            Phyllis Logan
# tt0039442                                 Hablamudita  José Luis López Vázquez
# tt0054724                                      Zombie            William Joyce
# ...                                               ...                      ...
# tt9908390                                      Lelion                Dany Boon
# tt9911196                  DeBeentjesvanSintHildegard           Herman Finkers
# tt9911774                    PadmavyuhathileAbhimanyu           Anoop Chandran
# tt9914286                            SokaginÇocuklari        Ahmet Faik Akinci
# tt9914942                       LavidasenselaSaraAmat     Maria Morera Colomer
#
# [70264 rows x 4 columns]

# %%
# Merge the movies_list with oscar_films_df on 'title_formatted'. In this merged data frame, we should be able to see all movie data plus the indication of which movies have won or been nominated in Oscar.
award_list_4 = pd.merge(movies_actors, oscar_films_df, how='left', on=['title_formatted','year'])

# Fill the non-winning/non-nominated movies with 'False'
award_list_4['oscar_win/nominated'] = award_list_4['oscar_win/nominated'].fillna(False)
award_list_4 = award_list_4.drop(columns=['film'])
award_list_4
# Out:
#        year                                             title  \
# 0      1983                            La glace à trois faces
# 1      2001                                    Kate & Leopold
# 2      1983  Another time, another place - Una storia d'amore
# 3      1973                                     Habla, mudita
# 4      1971                                            Zombie
# ...     ...                                               ...
# 70259  2020                                           Le lion
# 70260  2020                    De Beentjes van Sint-Hildegard
# 70261  2019                         Padmavyuhathile Abhimanyu
# 70262  2019                                 Sokagin Çocuklari
# 70263  2019                        La vida sense la Sara Amat
#
#                               title_formatted              actor_split  \
# 0                          Laglaceàtroisfaces          Jeanne Helbling
# 1                                 KateLeopold                 Meg Ryan
# 2      AnothertimeanotherplaceUnastoriadamore            Phyllis Logan
# 3                                 Hablamudita  José Luis López Vázquez
# 4                                      Zombie            William Joyce
# ...                                       ...                      ...
# 70259                                  Lelion                Dany Boon
# 70260              DeBeentjesvanSintHildegard           Herman Finkers
# 70261                PadmavyuhathileAbhimanyu           Anoop Chandran
# 70262                        SokaginÇocuklari        Ahmet Faik Akinci
# 70263                   LavidasenselaSaraAmat     Maria Morera Colomer
#
#        oscar_win/nominated
# 0                    False
# 1                     True
# 2                    False
# 3                    False
# 4                    False
# ...                    ...
# 70259                False
# 70260                False
# 70261                False
# 70262                False
# 70263                False
#
# [70264 rows x 5 columns]

# %%
# Create data frame to determine if there's any relationship between movie actors and awards.

actor_awards = award_list_4.groupby(['actor_split'])['oscar_win/nominated'].sum()

award_by_actor = pd.DataFrame(actor_awards)
award_by_actor = award_by_actor.sort_values('oscar_win/nominated', ascending=False)
award_by_actor_top = award_by_actor.head(15)
award_by_actor_top
# Out:
#                    oscar_win/nominated
# actor_split
# Robert Downey Jr.                    7
# Tom Hanks                            6
# Ryan Gosling                         5
# Tom Cruise                           5
# Hugh Jackman                         5
# Leonardo DiCaprio                    5
# Jeff Bridges                         5
# Meryl Streep                         4
# Jessica Lange                        4
# Johnny Depp                          4
# Warren Beatty                        4
# Kevin Spacey                         3
# Liam Neeson                          3
# Eddie Murphy                         3
# William H. Macy                      3

# %%
# Generate a line plot of movie actors/actresses versus oscar award counts 

# Set up x-axis & y-axis variable
actor_x_axis = award_by_actor_top['oscar_win/nominated'].index.tolist()
actor_y_axis = award_by_actor_top['oscar_win/nominated']


# Plot the line chart
plt.subplots(figsize=(12,8))
plt.xticks(rotation='vertical')

plt.plot(actor_x_axis,
         actor_y_axis)
plt.xlabel('Movie Actors/Actresses')
plt.ylabel('Number of Oscar Wins/Nominations')
plt.title('Oscar Favored Movie Actors/Actresses')
plt.show()

# %% [markdown]
# # The analysis below is to find movie directors' impacts on movie revenues.

# %%
# From the orignal merged_df_copy data frame, drop the unnecessary columns to obtain a list with ONLY the movie names, director names and worldwide revenues.
revenue_n_director = merged_df_copy[['year','title', 'title_formatted', 'worlwide_gross_income', 'director_split']]
revenue_n_director
# Out:
#                year                                             title  \
# imdb_title_id
# tt0017938      1983                            La glace à trois faces
# tt0035423      2001                                    Kate & Leopold
# tt0036606      1983  Another time, another place - Una storia d'amore
# tt0039442      1973                                     Habla, mudita
# tt0054724      1971                                            Zombie
# ...             ...                                               ...
# tt9908390      2020                                           Le lion
# tt9911196      2020                    De Beentjes van Sint-Hildegard
# tt9911774      2019                         Padmavyuhathile Abhimanyu
# tt9914286      2019                                 Sokagin Çocuklari
# tt9914942      2019                        La vida sense la Sara Amat
#
#                                       title_formatted  worlwide_gross_income  \
# imdb_title_id
# tt0017938                          Laglaceàtroisfaces                    NaN
# tt0035423                                 KateLeopold             76019048.0
# tt0036606      AnothertimeanotherplaceUnastoriadamore                    NaN
# tt0039442                                 Hablamudita                    NaN
# tt0054724                                      Zombie                    NaN
# ...                                               ...                    ...
# tt9908390                                      Lelion              3507171.0
# tt9911196                  DeBeentjesvanSintHildegard              7299062.0
# tt9911774                    PadmavyuhathileAbhimanyu                    NaN
# tt9914286                            SokaginÇocuklari                 2833.0
# tt9914942                       LavidasenselaSaraAmat                59794.0
#
#                         director_split
# imdb_title_id
# tt0017938                 Jean Epstein
# tt0035423                James Mangold
# tt0036606              Michael Radford
# tt0039442      Manuel Gutiérrez Aragón
# tt0054724                   Del Tenney
# ...                                ...
# tt9908390       Ludovic Colbeau-Justin
# tt9911196              Johan Nijenhuis
# tt9911774              Vineesh Aaradya
# tt9914286            Ahmet Faik Akinci
# tt9914942                    Laura Jou
#
# [70264 rows x 5 columns]

# %%
# Create a data frame to show how much movie revenues each director has made in total.
revenue_for_director = revenue_n_director.groupby(['director_split'])['worlwide_gross_income'].sum()
revenue_vs_director = pd.DataFrame(revenue_for_director)
# revenue_for_director
revenue_vs_director = revenue_vs_director.sort_values('worlwide_gross_income', ascending=False)

# Filter the top 15 most-wealthy directors.
revenue_vs_director_top = revenue_vs_director.head(15)

# Convert the revenue column (the 'worlwide_gross_income') column to show numbers in millions dollars.
revenue_vs_director_top["worlwide_gross_income"] = revenue_vs_director_top["worlwide_gross_income"] / 1000000
revenue_vs_director_top
# Out:
# <ipython-input-53-bf0b73e97d2f>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   revenue_vs_director_top["worlwide_gross_income"] = revenue_vs_director_top["worlwide_gross_income"] / 1000000
#                    worlwide_gross_income
# director_split
# Steven Spielberg            10521.265279
# Anthony Russo                6848.715547
# Peter Jackson                6601.458791
# Michael Bay                  6451.692798
# James Cameron                6185.441282
# David Yates                  6021.255883
# Christopher Nolan            4870.773767
# J.J. Abrams                  4653.989459
# Tim Burton                   4456.403545
# Ron Howard                   4390.732419
# Jon Favreau                  4348.727274
# Robert Zemeckis              4311.071335
# Chris Columbus               4134.539583
# Ridley Scott                 4114.600082
# Roland Emmerich              3994.574698

# %%
# Generate a line plot to show which directors impact movie revenues the most

# Set up x-axis & y-axis variable
director_revenue_x_axis = revenue_vs_director_top['worlwide_gross_income'].index.tolist()
director_revenue_y_axis = revenue_vs_director_top['worlwide_gross_income']


# Plot the line chart
plt.subplots(figsize=(12,8))
plt.xticks(rotation='vertical')

plt.plot(director_revenue_x_axis,
         director_revenue_y_axis)
plt.xlabel('Top Wealthy Movie Directors')
plt.ylabel('Total Revenue (in Million Dollars)')
plt.title('Total Movie Revenues by the Top 15 Movie Directors ')
plt.show()

# %% [markdown]
# # The analysis below is to how much holiday months can impact the movie revenues.

# %%
# Create a data frame from the originally merged data frame to keep only the 'date_published' and 'worlwide_gross_income' columns.
datetime_df = merged_df_copy[['date_published', 'worlwide_gross_income']]
datetime_df
# Out:
#               date_published  worlwide_gross_income
# imdb_title_id
# tt0017938         1983-03-13                    NaN
# tt0035423         2002-03-01             76019048.0
# tt0036606         1983-07-15                    NaN
# tt0039442         1973-06-01                    NaN
# tt0054724         1971-10-29                    NaN
# ...                      ...                    ...
# tt9908390         2020-01-29              3507171.0
# tt9911196         2020-02-13              7299062.0
# tt9911774         2019-03-08                    NaN
# tt9914286         2019-03-15                 2833.0
# tt9914942         2020-02-05                59794.0
#
# [70264 rows x 2 columns]

# %%
pip install sort-dataframeby-monthorweek
# Out:
# Requirement already satisfied: sort-dataframeby-monthorweek in c:\users\grace\anaconda3\lib\site-packages (0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sorted-months-weekdays
# Out:
# Requirement already satisfied: sorted-months-weekdays in c:\users\grace\anaconda3\lib\site-packages (0.2)Note: you may need to restart the kernel to use updated packages.

# %%
# Create a data frame to store the sum of movie revenues by months over the years.
date_n_revenue = pd.DataFrame(datetime_df.groupby(datetime_df['date_published'].dt.strftime('%B'))['worlwide_gross_income'].sum().sort_values())
date_n_revenue_copy = date_n_revenue.reset_index()
from sorted_months_weekdays import *
from sort_dataframeby_monthorweek import *
date_n_revenue = Sort_Dataframeby_Month(df=date_n_revenue_copy,monthcolumnname='date_published')

# Convert the revenue column (the 'worlwide_gross_income') column to show numbers in millions dollars.
date_n_revenue['worlwide_gross_income'] = date_n_revenue['worlwide_gross_income']/1000000
date_n_revenue
# Out:
#    date_published  worlwide_gross_income
# 0         January           64888.791962
# 1        February           56979.911129
# 2           March           57804.749482
# 3           April           61241.007993
# 4             May           51765.864429
# 5            June           42706.894404
# 6            July           41466.995193
# 7          August           51158.001101
# 8       September           72565.208861
# 9         October           77008.475681
# 10       November           56218.717764
# 11       December           77655.675075

# %%
# Set up x-axis & y-axis variable
date_revenue_x_axis = date_n_revenue['date_published'].tolist()
date_revenue_y_axis = date_n_revenue['worlwide_gross_income']


# Plot the line chart
plt.subplots(figsize=(12,8))
plt.xticks(rotation='vertical')

plt.bar(date_revenue_x_axis,
         date_revenue_y_axis)
plt.xlabel('Months')
plt.ylabel('Total Movie Revenues (in million dollars)')
plt.title('Movie Revenues Impacted by Months')
plt.show()

# %% [markdown]
# ## Think about what we can take from the graph above:
# * American holiday months are typically: November, December and January (Thanksgiving break, Christmas & New Year, and Winter breaks), and June, July and August (Summer breaks)
# * Other countries' holiday months may vary, for example: September and October are Chinese national holiday months.
# * Based on our graph above, we can see that:
# * 1. The most revenue-generated months are Dec, Oct, Sep, and Jan. All of them fall into the broad categories of holiday months.
# * 2. Summer seasons (Jun, Jul & Aug), however, generate the least total revenue. This may because summer breaks usually only applicable to students and some school faculties; therefore, it does not have such a big impact like other national holidays.
# * Conclusion:
# * - National holidays do have huge impacts on movie revenues -> this logic is worldwide.
# * - Students and school faculties may not be as impactful as working adults on movie revenues.

# %% [markdown]
# # The analysis below is to find movie genres' impacts on the movie revenues, both globally and in the U.S.

# %%
# Drop the unnecessary columns to obtain a list with ONLY the movie names and revenues.
movies_genres_2 = merged_df_copy[['genre_split','worlwide_gross_income', 'usa_gross_income']]
movies_genres_2
# Out:
#               genre_split  worlwide_gross_income  usa_gross_income
# imdb_title_id
# tt0017938           Drama                    NaN               NaN
# tt0035423          Comedy             76019048.0        47121859.0
# tt0036606           Drama                    NaN               NaN
# tt0039442           Drama                    NaN               NaN
# tt0054724          Horror                    NaN               NaN
# ...                   ...                    ...               ...
# tt9908390          Comedy              3507171.0               NaN
# tt9911196          Comedy              7299062.0               NaN
# tt9911774           Drama                    NaN               NaN
# tt9914286           Drama                 2833.0               NaN
# tt9914942           Drama                59794.0               NaN
#
# [70264 rows x 3 columns]

# %%
# Create a data frame to store the sum of global revenues by genre.
genre_n_revenue = pd.DataFrame(movies_genres_2.groupby(['genre_split'])['worlwide_gross_income'].sum().sort_values(ascending=False))
genre_n_revenue_copy = genre_n_revenue.reset_index()
genre_n_revenue_copy

# Convert the revenue column (the 'worlwide_gross_income') column to show numbers in millions dollars.
genre_n_revenue_copy['worlwide_gross_income'] = genre_n_revenue_copy['worlwide_gross_income']/1000000
genre_n_revenue_copy
# Out:
#     genre_split  worlwide_gross_income
# 0        Action          279632.420442
# 1        Comedy          135938.869806
# 2     Animation           89163.788495
# 3         Drama           76409.325688
# 4     Adventure           52364.694286
# 5         Crime           25169.732813
# 6     Biography           24228.811975
# 7        Horror           18921.893705
# 8        Family            2595.436470
# 9       Mystery            2317.243574
# 10      Fantasy            2129.596266
# 11      Romance             918.663274
# 12     Thriller             484.680843
# 13      Musical             445.100774
# 14       Sci-Fi             288.757210
# 15          War             281.246632
# 16      Western              70.502095
# 17      History              52.365140
# 18        Music              33.927970
# 19        Sport              11.207004
# 20  Documentary               2.028612
# 21        Adult               0.000000

# %%
# Set up x-axis & y-axis variable
genre_rev_x_axis = (genre_n_revenue_copy['genre_split'].drop_duplicates()).tolist()
genre_rev_y_axis = genre_n_revenue_copy['worlwide_gross_income']


# Plot the line chart
plt.subplots(figsize=(12,8))
plt.xticks(rotation='vertical')

plt.plot(genre_rev_x_axis,
         genre_rev_y_axis)
plt.xlabel('Genres')
plt.ylabel('Total Global Revenue (in million dollars)')
plt.title('Global Movie Revenues Generated by Genres')
plt.show()

# %%
# Create a data frame to store the sum of USA revenues by genre.
genre_n_revenue_us = pd.DataFrame(movies_genres_2.groupby(['genre_split'])['usa_gross_income'].sum().sort_values(ascending=False))
genre_n_revenue_us = genre_n_revenue_us.reset_index()


# Convert the revenue column (the 'usa_gross_income') column to show numbers in millions dollars.
genre_n_revenue_us['usa_gross_income'] = genre_n_revenue_us['usa_gross_income']/1000000
genre_n_revenue_us
# Out:
#     genre_split  usa_gross_income
# 0        Action     104037.708156
# 1        Comedy      66523.961768
# 2         Drama      32441.203945
# 3     Animation      31588.137463
# 4     Adventure      21258.818963
# 5     Biography      12154.641692
# 6         Crime      11857.780833
# 7        Horror       9933.709200
# 8        Family       1111.075012
# 9       Fantasy       1101.438145
# 10      Mystery        748.005581
# 11      Musical        206.416348
# 12     Thriller        157.471690
# 13      Romance        154.298136
# 14       Sci-Fi        136.448984
# 15      Western         74.138553
# 16        Music         13.991642
# 17  Documentary          2.028612
# 18          War          1.770244
# 19        Sport          1.208616
# 20        Adult          0.000000
# 21      History          0.000000

# %%
# Set up x-axis & y-axis variable
genre_rev_x_axis_us = (genre_n_revenue_us['genre_split'].drop_duplicates()).tolist()
genre_rev_y_axis_us = genre_n_revenue_us['usa_gross_income']


# Plot the line chart
plt.subplots(figsize=(12,8))
plt.xticks(rotation='vertical')

plt.plot(genre_rev_x_axis_us,
         genre_rev_y_axis_us)
plt.xlabel('Genres')
plt.ylabel('Total USA Revenue (in million dollars)')
plt.title('USA Movie Revenues Generated by Genres')
plt.show()

# %% [markdown]
# # The analysis below is to find how movie ratings can impact the total movie revenues.

# %%
# Drop unecessary columns to only keep 'weighted_average_vote' and 'worlwide_gross_income' columns.
rating_n_rev = merged_df_copy[['weighted_average_vote', 'worlwide_gross_income']]
rating_n_rev
# Out:
#                weighted_average_vote  worlwide_gross_income
# imdb_title_id
# tt0017938                        7.0                    NaN
# tt0035423                        6.4             76019048.0
# tt0036606                        6.5                    NaN
# tt0039442                        6.2                    NaN
# tt0054724                        3.5                    NaN
# ...                              ...                    ...
# tt9908390                        5.3              3507171.0
# tt9911196                        7.7              7299062.0
# tt9911774                        7.9                    NaN
# tt9914286                        6.4                 2833.0
# tt9914942                        6.7                59794.0
#
# [70264 rows x 2 columns]

# %%
# Create the bins in which Moving Ratings Data will be held
ratings_to_cut = [0, 1.9, 3.9, 5.9, 7.9, 10]
# Create the names for the bins
ratings_group_name = ['<2', '2-4', '4-6', '6-8', '8-10']

# Create rating groups using the dataset with non-duplicate players
ratings_groups = pd.cut(
    x=rating_n_rev['weighted_average_vote'],
    bins=ratings_to_cut,
    labels=ratings_group_name,
    include_lowest=True,
)


# Create data frame to show whether movies with higher ratings tend to have higher revenues.

rev_by_ratings = rating_n_rev.groupby(ratings_groups)['worlwide_gross_income'].sum()/1000000        # Convert the revenue column (the 'Revenue by Ratings') column to show numbers in millions dollars.

rev_n_rating = {
    'Revenue by Ratings': rev_by_ratings
}

revenue_by_rating = pd.DataFrame(rev_n_rating)

revenue_by_rating
# Out:
#                        Revenue by Ratings
# weighted_average_vote
# <2                             140.095693
# 2-4                           7208.170679
# 4-6                         136221.657986
# 6-8                         498723.660646
# 8-10                         69166.708070

# %%
# Plot a bar chart to plot the relationship between the rating and total revenues by ratings intervals

# Set x-axis and y-axis for rating and total revenues by ratings intervals
rating_intervals = np.arange(len(ratings_group_name))
rev_by_ratings_by_interval = rev_by_ratings.tolist()

# Set up the graph size and tick labels
plt.subplots(figsize=(12,8))
interval_names = ratings_group_name
xtick_location = [value for value in rating_intervals] 
plt.xticks(xtick_location, interval_names)

# Plot the bar chart and style the chart 
plt.bar(rating_intervals,
        rev_by_ratings_by_interval,
        width=0.5,
        align='center')
plt.xlim(-0.5, len(rating_intervals)-0.5)
plt.title('Ratings Impacts on Total Movie Revenues')
plt.xlabel('IMDB Ratings Intervals')
plt.ylabel('Total Movie Revenues (in million dollars)')
plt.show()

# %% [markdown]
# ## Think about why highest rating does NOT necessarily result in highest revenue:
# * Similar to rating's impact on awards, the ratings of movies do not have much impact on movie revenues. Rather, revenues are more likely to be impacted by genres and time frame.
# * Based on our analysis earlier, Action movies has significantly higher revenues than any other genres, and as most people know, action movies do not tend to receive very high ratings nor many awards.
# * Most of the award-winning movies are Drama movies, which do likely to receive higher ratings but lower revenues.
# * We will continue to see how audience genders may have some impact on their preferences of movie genres (see below).

# %% [markdown]
# # The analysis below is to find audience gender percentages in giving out movie ratings.

# %%
gender_ratings = pd.DataFrame(merged_df_copy[['males', 'females']])
gender_ratings
# Out:
#                  males  females
# imdb_title_id
# tt0017938       1096.0    170.0
# tt0035423      69268.0  53551.0
# tt0036606        322.0     54.0
# tt0039442        151.0     47.0
# tt0054724       1750.0    215.0
# ...                ...      ...
# tt9908390        514.0     50.0
# tt9911196        793.0    215.0
# tt9911774          7.0      0.0
# tt9914286         19.0      3.0
# tt9914942        132.0     29.0
#
# [70264 rows x 2 columns]

# %%
total_rating = (pd.DataFrame(gender_ratings[['males', 'females']].sum())).sum()
male_rating = gender_ratings['males'].sum()
female_rating =  gender_ratings['females'].sum()

gender_rating_df = pd.DataFrame({'Total Gender Votes': [male_rating, female_rating]},
                                  index=['Male', 'Female'])
gender_rating_df
# Out:
#         Total Gender Votes
# Male           949916488.0
# Female         215719099.0

# %%
male_rating/total_rating
# Out:
# 0    0.814934
# dtype: float64

# %%
gender_rating_df.plot.pie(y='Total Gender Votes', 
                          figsize=(10, 10), 
                          explode=[.1,0],
                          title='Gender Rating Percentages')
plt.show()

# %% [markdown]
# ## Refer to the last analysis ->
# * action movies generates the most revenue + action movies do not tend to receive higher review.
# * 81% of audiences who gave review over the years are male. This also enhance the idea that action movies are extremely popular because men love those --> high revenue on action movie.
